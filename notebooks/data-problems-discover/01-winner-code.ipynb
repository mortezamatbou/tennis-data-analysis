# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/raw/01/MatchEventInfo.parquet')

# %%
df[df['winner_code'].isnull()]
# Out:
#        match_id  first_to_serve home_team_seed away_team_seed  custom_id  \
# 241    12287007             2.0             WC           None   CrJscCjh
# 245    12287010             NaN           None           None   BlBsoPij
# 252    12288050             NaN              3           None   RCvsVlec
# 253    12288414             NaN           None           None  afgesWMgi
# 254    12288414             NaN           None           None  afgesWMwe
# ...         ...             ...            ...            ...        ...
# 19389  12379710             NaN           None           None   AHtsgjuc
# 19391  12379712             NaN           None           None   EMUsRghb
# 19394  12379723             NaN           None           None  oKbcoeWHc
# 19535  12381829             NaN           None           None  zFFcsbFdd
# 19536  12381829             NaN           None           None  zFFcsbFed
#
#        winner_code  default_period_count  start_datetime  \
# ...

# %%
df = pd.read_parquet('../data/raw/01/GameInfo.parquet')
# Out:
#        match_id  set_id  game_id  point_id home_point away_point  \
# 28259  12287007       1        1         2         15         30
# 28260  12287007       1        1         3         15         40
# 28257  12287007       1        1         0          0         15
# 28261  12287007       1        1         4         30         40
# 28258  12287007       1        1         1          0         30
# 28253  12287007       1        2         0         15          0
# 28256  12287007       1        2         3         40         15
# 28254  12287007       1        2         1         30          0
# 28255  12287007       1        2         2         30         15
# 28252  12287007       1        3         3         15         40
# 28250  12287007       1        3         1          0         30
# 28249  12287007       1        3         0          0         15
# 28251  12287007       1        3         2         15         30
# ...

# %%
df[df['match_id'] == 12287007].sort_values(by='game_id', ascending=True)
# Out:
#        match_id  set_id  game_id  point_id home_point away_point  \
# 28259  12287007       1        1         2         15         30
# 28260  12287007       1        1         3         15         40
# 28257  12287007       1        1         0          0         15
# 28261  12287007       1        1         4         30         40
# 28258  12287007       1        1         1          0         30
# 28253  12287007       1        2         0         15          0
# 28256  12287007       1        2         3         40         15
# 28254  12287007       1        2         1         30          0
# 28255  12287007       1        2         2         30         15
# 28252  12287007       1        3         3         15         40
# 28250  12287007       1        3         1          0         30
# 28249  12287007       1        3         0          0         15
# 28251  12287007       1        3         2         15         30
# ...

# %%
df[df['match_id'] == 12287010].sort_values(by='game_id', ascending=True)
# Out:
# Empty DataFrame
# Columns: [match_id, set_id, game_id, point_id, home_point, away_point, point_description, home_point_type, away_point_type, home_score, away_score, serving, scoring]
# Index: []
